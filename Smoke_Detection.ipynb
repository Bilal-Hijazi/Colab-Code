# %% [markdown]
# <a href="https://colab.research.google.com/github/Bilal-Hijazi/Colab-Code/blob/main/Smoke_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-259444f5-7121-452b-a36f-e12fa5abfff7" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-259444f5-7121-452b-a36f-e12fa5abfff7">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("smoke_detection_iot.csv")
data.head()

# %%
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
from sklearn.model_selection import train_test_split
import numpy as np
import pandas as pd

data = pd.read_csv("smoke_detection_iot.csv")

for col in data.columns[data.columns != 'Fire Alarm']:
    # Calculate the average for each column
    avg = data[col].mean()
    # Convert numerical values to binary based on the average
    data[col] = (data[col] > avg).astype(int)

X = data.drop("Fire Alarm", axis=1)
y = data["Fire Alarm"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Apply SMOTE to balance the class distribution
smote = SMOTE(random_state=42)
X_train_balanced, y_train_balanced = smote.fit_resample(X_train, y_train)

results = {}

for r in np.arange(0.9, 0, -0.1):
    clf = RandomForestClassifier(random_state=42)
    clf.fit(X_train_balanced, y_train_balanced)
    y_pred = clf.predict(X_test)
    precision = precision_score(y_test, y_pred, zero_division=0)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    accuracy = accuracy_score(y_test, y_pred)
    results[round(r, 1)] = {'Precision': round(precision, 3), 'Recall': round(recall, 3), 'F1 Score': round(f1, 3), 'Accuracy': round(accuracy, 3)}

# Print the results
pd.DataFrame(results)

# %%
from xgboost import XGBClassifier
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
import numpy as np
import pandas as pd

data = pd.read_csv("smoke_detection_iot.csv")

for col in data.columns[data.columns != 'Fire Alarm']:
    # Calculate the average for each column
    avg = data[col].mean()
    # Convert numerical values to binary based on the average
    data[col] = (data[col] > avg).astype(int)

X = data.drop("Fire Alarm", axis=1)
y = data["Fire Alarm"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Apply SMOTE to balance the class distribution
smote = SMOTE(random_state=42)
X_train_balanced, y_train_balanced = smote.fit_resample(X_train, y_train)

results = {}

for r in np.arange(0.9, 0, -0.1):
    # Selecting fraction r of positive class instances
    positive_indices = np.where(y_train_balanced == 1)[0]
    np.random.shuffle(positive_indices)
    selected_positive_indices = positive_indices[:int(r * len(positive_indices))]
    negative_indices = np.where(y_train_balanced == 0)[0]

    # Creating imbalanced training dataset
    imbalanced_train_indices = np.concatenate((selected_positive_indices, negative_indices))
    X_train_imbalanced = X_train_balanced.iloc[imbalanced_train_indices]
    y_train_imbalanced = y_train_balanced.iloc[imbalanced_train_indices]

    # Training the XGB Classifier
    xgb = XGBClassifier()
    xgb.fit(X_train_imbalanced, y_train_imbalanced)

    # Predictions and recording precision, recall, F1 score, and accuracy
    y_pred = xgb.predict(X_test)
    precision = precision_score(y_test, y_pred, zero_division=0)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    accuracy = accuracy_score(y_test, y_pred)
    results[round(r, 1)] = {'Precision': round(precision, 3), 'Recall': round(recall, 3), 'F1 Score': round(f1, 3), 'Accuracy': round(accuracy, 3)}

# Print the results
pd.DataFrame(results)

Precision 0.979	0.979	0.999	0.999	0.989	1.000	0.999	0.999	1.000
Recall	0.997	0.987	0.987	0.997	0.967	0.881	0.781	0.881	0.678
F1 Score	0.941	0.941	0.941	0.941	0.941	0.877	0.877	0.877	0.875
Accuracy	95.6 	95.69 95.6	95.6	95.6	95.6	95.6	95.6	95.6

# %%
from sklearn import svm
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
import numpy as np
import pandas as pd

data = pd.read_csv("smoke_detection_iot.csv")

for col in data.columns[data.columns != 'Fire Alarm']:
    # Calculate the average for each column
    avg = data[col].mean()
    # Convert numerical values to binary based on the average
    data[col] = (data[col] > avg).astype(int)

X = data.drop("Fire Alarm", axis=1)
y = data["Fire Alarm"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Apply SMOTE to balance the class distribution
smote = SMOTE(random_state=42)
X_train_balanced, y_train_balanced = smote.fit_resample(X_train, y_train)

results = {}

for r in np.arange(0.9, 0, -0.1):
    # Selecting fraction r of positive class instances
    positive_indices = np.where(y_train_balanced == 1)[0]
    np.random.shuffle(positive_indices)
    selected_positive_indices = positive_indices[:int(r * len(positive_indices))]
    negative_indices = np.where(y_train_balanced == 0)[0]

    # Creating imbalanced training dataset
    imbalanced_train_indices = np.concatenate((selected_positive_indices, negative_indices))
    X_train_imbalanced = X_train_balanced.iloc[imbalanced_train_indices]
    y_train_imbalanced = y_train_balanced.iloc[imbalanced_train_indices]

    # Training the SVM Classifier
    clf = svm.SVC()
    clf.fit(X_train_imbalanced, y_train_imbalanced)

    # Predictions and recording precision, recall, F1 score, and accuracy
    y_pred = clf.predict(X_test)
    precision = precision_score(y_test, y_pred, zero_division=0)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    accuracy = accuracy_score(y_test, y_pred)
    results[round(r, 1)] = {'Precision': round(precision, 3), 'Recall': round(recall, 3), 'F1 Score': round(f1, 3), 'Accuracy': round(accuracy * 100, 2)}

# Print the results
pd.DataFrame(results)

# %%
import tensorflow as tf
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
import numpy as np
import pandas as pd

data = pd.read_csv("smoke_detection_iot.csv")

# Assuming "Fire Alarm" is the target column
X = data.drop("Fire Alarm", axis=1)
y = data["Fire Alarm"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Apply SMOTE to balance the class distribution
smote = SMOTE(random_state=42)
X_train_balanced, y_train_balanced = smote.fit_resample(X_train, y_train)

results = {}

for r in np.arange(0.9, 0, -0.1):
    # Selecting fraction r of positive class instances
    positive_indices = np.where(y_train_balanced == 1)[0]
    np.random.shuffle(positive_indices)
    selected_positive_indices = positive_indices[:int(r * len(positive_indices))]
    negative_indices = np.where(y_train_balanced == 0)[0]

    # Creating imbalanced training dataset
    imbalanced_train_indices = np.concatenate((selected_positive_indices, negative_indices))
    X_train_imbalanced = X_train_balanced.iloc[imbalanced_train_indices]
    y_train_imbalanced = y_train_balanced.iloc[imbalanced_train_indices]

    # Building the TensorFlow model
    model = tf.keras.Sequential([
        tf.keras.layers.Input(shape=(X_train.shape[1],)),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(1, activation='sigmoid')
    ])
    model.compile(optimizer='adam',
                  loss='binary_crossentropy',
                  metrics=['accuracy'])

    # Training the model
    model.fit(X_train_imbalanced, y_train_imbalanced, epochs=10, batch_size=32, verbose=0)

    # Predictions and recording precision, recall, F1 score, and accuracy
    y_pred_prob = model.predict(X_test)
    y_pred = (y_pred_prob > 0.5).astype(int)  # Converting probabilities to binary predictions
    precision = precision_score(y_test, y_pred, zero_division=0)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    accuracy = accuracy_score(y_test, y_pred)
    results[round(r, 1)] = {'Precision': round(precision, 3), 'Recall': round(recall, 3), 'F1 Score': round(f1, 3), 'Accuracy': round(accuracy, 3)}

# Print the results
pd.DataFrame(results)

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
import pandas as pd

data = pd.read_csv("smoke_detection_iot.csv")

# Assuming "Fire Alarm" is the target column
X = data.drop("Fire Alarm", axis=1)
y = data["Fire Alarm"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Apply SMOTE to balance the class distribution
smote = SMOTE(random_state=42)
X_train_balanced, y_train_balanced = smote.fit_resample(X_train, y_train)

results = {}

for r in np.arange(0.9, 0, -0.1):
    # Selecting fraction r of positive class instances
    positive_indices = np.where(y_train_balanced == 1)[0]
    np.random.shuffle(positive_indices)
    selected_positive_indices = positive_indices[:int(r * len(positive_indices))]
    negative_indices = np.where(y_train_balanced == 0)[0]

    # Creating imbalanced training dataset
    imbalanced_train_indices = np.concatenate((selected_positive_indices, negative_indices))
    X_train_imbalanced = X_train_balanced.iloc[imbalanced_train_indices]
    y_train_imbalanced = y_train_balanced.iloc[imbalanced_train_indices]

    # Initialize and train the MLPClassifier
    mlp = MLPClassifier(hidden_layer_sizes=(64, 64), activation='relu', random_state=42)
    mlp.fit(X_train_imbalanced, y_train_imbalanced)

    # Predictions and recording precision, recall, F1 score, and accuracy
    y_pred = mlp.predict(X_test)
    precision = precision_score(y_test, y_pred, zero_division=0)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    accuracy = accuracy_score(y_test, y_pred)
    results[round(r, 1)] = {'Precision': round(precision, 3), 'Recall': round(recall, 3), 'F1 Score': round(f1, 3), 'Accuracy': round(accuracy, 3)}

# Print the results
pd.DataFrame(results)
